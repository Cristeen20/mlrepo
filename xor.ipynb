# %% [markdown]
# <a href="https://colab.research.google.com/github/Cristeen20/mlrepo/blob/master/xor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from tensorflow import keras
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
training_data=np.array([[0,0],[0,1],[1,0],[1,1]],"float32")
target_data = np.array([ [0], [1], [1], [0] ], "float32")

# %%
model=keras.models.Sequential()
model.add(keras.layers.Dense(units=16,input_dim=2,activation='relu'))
model.add(keras.layers.Dense(1,activation='sigmoid'))
model.compile(loss='mean_squared_error',optimizer='adam',metrics=['binary_accuracy'])

# %%
model.fit(training_data, target_data, nb_epoch=250, verbose=2)
print(model.predict(training_data).round())
# Out:
# WARNING:tensorflow:The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 4 samples
# Epoch 1/250
# 4/4 - 0s - loss: 0.2577 - binary_accuracy: 0.5000
# Epoch 2/250
# 4/4 - 0s - loss: 0.2574 - binary_accuracy: 0.2500
# Epoch 3/250
# 4/4 - 0s - loss: 0.2570 - binary_accuracy: 0.5000
# Epoch 4/250
# 4/4 - 0s - loss: 0.2567 - binary_accuracy: 0.5000
# Epoch 5/250
# 4/4 - 0s - loss: 0.2563 - binary_accuracy: 0.5000
# Epoch 6/250
# 4/4 - 0s - loss: 0.2560 - binary_accuracy: 0.5000
# Epoch 7/250
# 4/4 - 0s - loss: 0.2556 - binary_accuracy: 0.5000
# Epoch 8/250
# 4/4 - 0s - loss: 0.2553 - binary_accuracy: 0.5000
# Epoch 9/250
# 4/4 - 0s - loss: 0.2549 - binary_accuracy: 0.5000
# Epoch 10/250
# 4/4 - 0s - loss: 0.2546 - binary_accuracy: 0.5000
# Epoch 11/250
# 4/4 - 0s - loss: 0.2542 - binary_accuracy: 0.5000
# Epoch 12/250
# 4/4 - 0s - loss: 0.2539 - binary_accuracy: 0.5000
# Epoch 13/250
# 4/4 - 0s - loss: 0.2536 - binary_accuracy: 0.5000
# Epoch 14/250
# ...
